# %% [markdown]
# # Automatic data collection on the Web

# %% [markdown]
# Before we start to tackle some nice web pages (html), we will discover the xml language which is a good introduction to data web scraping

# %% [markdown]
# ### XML

# %% [markdown]
# XML was created to facilitate data exchange between machines and software.
#
# XML is a language that is written using tags.
#
# XML is a W3C recommendation, so it is a technology with strict rules to follow.
#
# XML is intended to be understandable by everyone: people and machines alike.
#
# XML allows us to create our own vocabulary using a set of customizable rules and tags.

# %% [markdown]
# XML is also compatible with the web so that data exchanges can be easily carried out over the Internet.
#
# XML is therefore standardized, simple, but above all extensible and configurable so that any type of data can be described.

# %% [markdown]
# Here is an example of an XML document, which we have saved as data.xml in the data directory
#
# Display its content

# %%
file = open("../data/data.xml", "r")
print (file.read())
file.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <users>
#     <user data-id="101">
#         <nom>Zorro</nom>
#         <metier>Danseur</metier>
#     </user>
#     <user data-id="102">
#         <nom>Hulk</nom>
#         <metier>Footballeur</metier>
#     </user>
#     <user data-id="103">
#         <nom>Zidane</nom>
#         <metier>Star</metier>
#     </user>
#     <user data-id="104">
#         <nom>Beans</nom>
#         <metier>Epicier</metier>
#     </user>
#     <user data-id="105">
#         <nom>Batman</nom>
#         <metier>Veterinaire</metier>
#     </user>
#     <user data-id="106">
#         <nom>Spiderman</nom>
#         <metier>Veterinaire</metier>
#     </user>
# </users>

# %% [markdown]
# The first line indicates the encoding, we always stay in the UTF-8 encoding. Then we notice that the "users" tag has other "user" tags that themselves have their own tags. The data is hierarchized in a tree and each node provides information.

# %% [markdown]
# Here is a small script that displays all the user names.

# %%
from lxml import etree
# I define my source document
tree = etree.parse("../data/data.xml")
# I look at my document and identify the tag path to get to the "user" information
# Indeed, the information is in a name tag itself present in a user tag
# it even presents itself in a users tag. This last tag is located at the root of the directory
# so in tree.xpath("/users/user/name") there are the tags associated with our search
for user in tree.xpath("/users/user/nom"):
    # I want to display only the content (.text) of these tags /users/user/name
    print(user.text)
# Out:
# Zorro
# Hulk
# Zidane
# Beans
# Batman
# Spiderman

# %%
tree.xpath("/users/user/nom")[0].text
# Out:
# 'Zorro'

# %%
# You can display the attributes of the tags that store this information
tree = etree.parse("../data/data.xml")
for user in tree.xpath("/users/user"):
    print(user.get("data-id"))
# Out:
# 101
# 102
# 103
# 104
# 105
# 106

# %% [markdown]
# You can refine the display by proposing to display only users whose job is Veterinary

# %%
tree = etree.parse("../data/data.xml")
# Quel joli petit dictionnaire
for user in tree.xpath("/users/user[metier='Veterinaire']/nom"):
    print(user.text)
# Out:
# Batman
# Spiderman

# %% [markdown]
# # Data web scrapping

# %% [markdown]
# We saw earlier how to parse XML, it is also possible to parse HTML and the tool that does the job best in my opinion is the BeautifulSoup librairy

# %% [markdown]
# Save a web page (for example becode.org) that you like in the data directory, and display its content (the xxx.html file)
#
# Put the content of this page in a variable, for example html_doc

# %%
file = open("../data/becode.html", "r")
#print(fichier.read())
html_doc=file.read()
file.close()
html_doc
# Out:
# '<!DOCTYPE HTML>\n<html lang="en">\n\n<head>\n\t<title>BeCode.org for Friends</title>\n\t<meta charset="utf-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<!--[if lte IE 8]><script src="assets/js/ie/html5shiv.js"></script><![endif]-->\n\t<link rel="stylesheet" href="assets/css/main.css" />\n\t<!--[if lte IE 8]><link rel="stylesheet" href="assets/css/ie8.css" /><![endif]-->\n\t<!--[if lte IE 9]><link rel="stylesheet" href="assets/css/ie9.css" /><![endif]-->\n\t<meta property="og:type" content="business.business">\n\t<meta property="og:title" content="BeCode | Free Coding School">\n\t<meta property="og:description" content="Offering web development trainings for individuals.">\n\t<meta property="og:url" content="https://www.becode.org/partners/">\n\t<meta property="og:image" content="https://www.becode.org/partners/images/IngloriousBasterdz.jpg">\n\t<meta property="business:contact_data:country_name" content="Belgium">\n\t<link rel="canonical" href="https://www.becode.org/partners">\n\t<link rel="icon" type="image/png" sizes="32x32" href="./assets/icons/favicon.ico">\n\t<link rel="icon" type="image/png" sizes="192x192" href="./assets/icons/favicon.ico">\n\t<link rel="icon" type="image/png" sizes="16x16" href="./assets/icons/favicon.ico">\n</head>\n\n<body>\n\t<!-- Nav -->\n\t<nav id="nav">\n\t\t<div class="menu">\n\t\t\t<a class="logo" href="../"><img width="40" src="images/logoblanc.png" alt="logo becode blanc"></a>\n\t\t\t<button href="#" class="menu-mobile"><i class="fa fa-bars"></i></button>\n\t\t\t<ul class="container clearfix">\n\t\t\t\t<li><a href="../register">Register at BeCode</a></li>\n\t\t\t\t<li><a href="../hire">Hire a learner</a></li>\n\t\t\t\t<li><a href="../partners">Why choose BeCode?</a></li>\n\t\t\t</ul>\n\t\t</div>\n\t</nav>\n\t<!-- Home -->\n\t<div class="wrapper style1 first">\n\t\t<article class="container" id="top">\n\t\t\t<div class="row">\n\t\t\t\t<div class="4u 12u(mobile)">\n\t\t\t\t\t<span class="image fit"><img src="images/SmallLogo.png" alt="Logo" /></span>\n\t\t\t\t</div>\n\t\t\t\t<div class="8u 12u(mobile)">\n\t\t\t\t\t<header>\n\t\t\t\t\t\t<h1><strong>BeCode.org</strong></h1>\n\t\t\t\t\t</header>\n\t\t\t\t\t<p>\n\t\t\t\t\t\tOur mission : Enabling tomorrow\'s digital talents to blossom. <br />\n\t\t\t\t\t\tWe believe that education makes anything possible. <br />\n\t\t\t\t\t\tSince 2017, BeCode has been offering free training courses for jobseekers to become web developers in partnership\n\t\t\t\t\t\twith Simplon. <br />\n\t\t\t\t\t</p>\n\t\t\t\t\t<p>Hereâ\x80\x99s how you can <strong>help</strong>!</p>\n\t\t\t\t\t<a href="#why" class="button big scrolly">Why BeCode?</a>\n\t\t\t\t</div>\n\t\t\t</div>\n\t\t</article>\n\t</div>\n\n\t<!-- why -->\n\t<div class="wrapper style2">\n\t\t<article id="why">\n\t\t\t<header>\n\t\t\t\t<h2>A school to address the skills gap in an inclusive way</h2>\n\t\t\t\t<p>Opportunities and talents currently remain untapped due to a skills gap: <br />\n\t\t\t\t\tthe gap between what employers need and what job seekers are offering today.</p>\n\t\t\t</header>\n\t\t\t<h3>Facts:</h3>\n\t\t\t<div class="container">\n\t\t\t\t<div class="row">\n\t\t\t\t\t<div class="4u 12u(mobile)">\n\t\t\t\t\t\t<section class="box style1">\n\t\t\t\t\t\t\t<span class="icon featured fa-bar-chart"></span>\n\t\t\t\t\t\t\t<h3>23%</h3>\n\t\t\t\t\t\t\t<p>of Belgian <strong>youth</strong> are <strong>unemployed</strong>.</p>\n\t\t\t\t\t\t</section>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div class="4u 12u(mobile)">\n\t\t\t\t\t\t<section class="box style1">\n\t\t\t\t\t\t\t<span class="icon featured fa-user-times"></span>\n\t\t\t\t\t\t\t<h3>30.000</h3>\n\t\t\t\t\t\t\t<p>vacancies in Belgium by 2020 due to <strong>shortfall</strong> of e-skilled workers.</p>\n\t\t\t\t\t\t</section>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div class="4u 12u(mobile)">\n\t\t\t\t\t\t<section class="box style1">\n\t\t\t\t\t\t\t<span class="icon featured fa-graduation-cap"></span>\n\t\t\t\t\t\t\t<h3>70%</h3>\n\ ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, "lxml")
# In my file (becode.org) by looking at this html script We can see that the main title is arranged in the h1 tag

for p in soup.find_all('h1'):
    # We only retrieve the content ==> .text
    print (p.text)
# Out:
# BeCode.org

# %% [markdown]
# Do the same with H2 tags

# %% [markdown]
# And now, do the same with the "p" tags

# %% [markdown]
# ### Scrapping via request HTTP

# %% [markdown]
# HTTP is a kind of language that will allow the client (you, through your browser for example) to communicate with a server connected to the network (the HTTP server installed on a site's server, for example Apache).
#
# Requests always go in pairs: the request (from the client) and the response (from the server).
# If this is not the case, it is because a problem has occurred at a point in the network.
#
# The syntax of the request (= client request) is always the same:
# - Command line (Command, URL, Protocol version)

# %% [markdown]
# Command is the method to use, it specifies the type of request, it can have the values :
#
#
# GET
# This is the most common way to request a resource. A GET request has no effect on the resource, it must be possible to repeat the request without effect.
#
# HEAD
# This method only asks for information about the resource, without asking for the resource itself.
#
# POST
# This method must be used when a request modifies the resource.
#
# OPTIONS
# This method allows you to obtain the communication options of a resource or the server in general.
#
# CONNECT
# This method allows you to use a proxy as a communication tunnel.
#
# TRACE
# This method asks the server to return what it has received, in order to test and diagnose the connection.
#
# PUT
# This method allows you to add a resource to the server.
#
# DELETE
# This method allows you to delete a resource from the server.
#
# I will only discuss the most common ones here: HEAD, GET and POST.

# %% [markdown]
# ### Putting it into practice

# %%
import requests
# Url of website
url='https://www.becode.org/partners/index.html'
# I send my HTTP request with a "GET" to the site server to identify in the url
r = requests.get(url)
# I display the requested url and the return of the server
print(url, r.status_code)
# I ask beautifulSoup to keep in a soup variable the web page to scrape (url) an html script
soup = BeautifulSoup(r.content,'lxml')
soup
# Out:
# https://becode.org/about/ 200
# <!DOCTYPE HTML>
# <html lang="en">
# <head>
# <title>BeCode.org for Friends</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--[if lte IE 8]><script src="assets/js/ie/html5shiv.js"></script><![endif]-->
# <link href="assets/css/main.css" rel="stylesheet"/>
# <!--[if lte IE 8]><link rel="stylesheet" href="assets/css/ie8.css" /><![endif]-->
# <!--[if lte IE 9]><link rel="stylesheet" href="assets/css/ie9.css" /><![endif]-->
# <meta content="business.business" property="og:type"/>
# <meta content="BeCode | Free Coding School" property="og:title"/>
# <meta content="Offering web development trainings for individuals." property="og:description"/>
# <meta content="https://www.becode.org/partners/" property="og:url"/>
# <meta content="https://www.becode.org/partners/images/IngloriousBasterdz.jpg" property="og:image"/>
# <meta content="Belgium" property="business:contact_data:country_name"/>
# <link href="https://www.becode.org/partners" rel="canonical"/>
# <link href="./assets/icons/favicon.ico" rel="icon" sizes="32x32" type="image/png"/>
# <link href="./assets/icons/favicon.ico" rel="icon" sizes="192x192" type="image/png"/>
# <link href="./assets/icons/favicon.ico" rel="icon" sizes="16x16" type="image/png"/>
# </head>
# <body>
# <!-- Nav -->
# <nav id="nav">
# <div class="menu">
# <a class="logo" href="../"><img alt="logo becode blanc" src="images/logoblanc.png" width="40"/></a>
# <button class="menu-mobile" href="#"><i class="fa fa-bars"></i></button>
# <ul class="container clearfix">
# <li><a href="../register">Register at BeCode</a></li>
# <li><a href="../hire">Hire a learner</a></li>
# <li><a href="../partners">Why choose BeCode?</a></li>
# </ul>
# </div>
# </nav>
# <!-- Home -->
# <div class="wrapper style1 first">
# <article class="container" id="top">
# <div class="row">
# <div class="4u 12u(mobile)">
# <span class="image fit"><img alt="Logo" src="images/SmallLogo.png"/></span>
# </div>
# <div class="8u 12u(mobile)">
# <header>
# <h1><strong>BeCode.org</strong></h1>
# </header>
# <p>
# 						Our mission : Enabling tomorrow's digital talents to blossom. <br/>
# 						We believe that education makes anything possible. <br/>
# 						Since 2017, BeCode has been offering free training courses for jobseekers to become web developers in partnership
# 						with Simplon. <br/>
# </p>
# <p>Here’s how you can <strong>help</strong>!</p>
# <a class="button big scrolly" href="#why">Why BeCode?</a>
# </div>
# </div>
# </article>
# </div>
# <!-- why -->
# <div class="wrapper style2">
# <article id="why">
# <header>
# <h2>A school to address the skills gap in an inclusive way</h2>
# <p>Opportunities and talents currently remain untapped due to a skills gap: <br/>
# 					the gap between what employers need and what job seekers are offering today.</p>
# </header>
# <h3>Facts:</h3>
# <div class="container">
# <div class="row">
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-bar-chart"></span>
# <h3>23%</h3>
# <p>of Belgian <strong>youth</strong> are <strong>unemployed</strong>.</p>
# </section>
# </div>
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-user-times"></span>
# <h3>30.000</h3>
# <p>vacancies in Belgium by 2020 due to <strong>shortfall</strong> of e-skilled workers.</p>
# </section>
# </div>
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-graduation-cap"></span>
# <h3>70%</h3>
# <p>of employers blame <strong>inadequate training</strong> for the shortfall in skilled workers.</p>
# </section>
# </div>
# </div>
# </div>
# <footer>
# <p>
# 					Whereas a large amount of digital job vacancies remain unfilled - and that number will increase dramatically in
# 					the years to come -<br/>
# 					most of these professions don't require an engineering degree at all.<br/> <br/>
# 					With a logical mindset, a lot of motivation and some basic training,<br/>
# 					anyone can learn to create mobile applications and websites and turn that into a profession!
# 				</p>
# <a class="button big scrolly" href="#how">How?</a>
# </footer>
# </article>
# </div>
# <!-- how -->
# <div class="wrapper style3">
# <article id="how">
# <header>
# <h2>A Belgian coding school, powered by a methodology with a proven track record</h2>
# <p>
# 					Intensive 7-month coding school program.<br/>
# 					Learn web and mobile development and turn that into a profession.<br/>
# 					Free-of-charge training, open to all, with motivation as key driver.
# 				</p> <br/>
# <p>BeCode is proud to be powered by <a href="http://simplon.co" target="_blank">Simplon.co</a>.<br/>
# 				A methodology with solid references and excellent results.</p>
# </header>
# <h3>Facts:</h3>
# <div class="container">
# <div class="row">
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-university"></span>
# <h3>30 schools</h3>
# <p>in France, Romania and South-Africa.</p>
# </section>
# </div>
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-users"></span>
# <h3>1114 on-site students</h3>
# <p>along with 2.500 online students and 12.300 children made familiar with technology.</p>
# </section>
# </div>
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-eur"></span>
# <h3>78% positive outcome</h3>
# <p>within 6 months, 78% of students have found a <strong>job</strong>, have created their own startup or started
# 								an advanced training.</p>
# </section>
# </div>
# </div>
# </div>
# <footer>
# <p>BeCode aims at providing competitive and responsible coding school programs, accessible to all.
# 					<br/>The program
# 					provides individual support for securing a sustainable profession.</p>
# <p>BeCode already launched six training centers in Brussels, Charleroi, Genk, Liège, Antwerp and Ghent and is looking forward to opening promotions all over the country. </p>
# <p>BeCode centers will open up all over the country, partnering each time with local stakeholders working alongside our future students and employers!</p>
# </footer>
# </article>
# </div>
# <!-- Nos Stats -->
# <div class="stats">
# <header id="stats">
# <h2>Realtime Stats</h2>
# </header>
# <div class="loading-content">
# <div class="loading-circle"></div>
# <span class="loading-name">LOADING</span>
# </div>
# <div class="container">
# <div class="statsContent"><p class="label"> Trained or Being trained</p><p class="data" data-values="329" id="valueTrained or Being trained"> 0  </p></div><div class="statsContent"><p class="label"> Positive ouput</p><p class="data" data-values="85%" id="valuePositive ouput"> 0  </p></div><div class="statsContent"><p class="label"> Code initiation given for free</p><p class="data" data-values="566" id="valueCode initiation given for free"> 0  </p></div><div class="statsContent"><p class="label"> Hackathons</p><p class="data" data-values="11" id="valueHackathons"> 0  </p></div><div class="statsContent"><p class="label"> Free websites for non-profits</p><p class="data" data-values="78" id="valueFree websites for non-profits"> 0  </p></div><div class="statsContent"><p class="label"> Meetups</p><p class="data" data-values="22" id="valueMeetups"> 0  </p></div><div class="statsContent"><p class="label"> Candidates applications</p><p class="data" data-values="1234" id="valueCandidates applications"> 0  </p></div><div class="statsContent"><p class="label"> MVP's</p><p class="data" data-values="21" id="valueMVP" s=""> 0  </p></div><div class="statsContent"><p class="label"> Internships</p><p class="data" data-values="95" id="valueInternships"> 0  </p></div><div class="statsContent"><p class="label"> Entreprises hosted intern</p><p class="data" data-values="96" id="valueEntreprises hosted intern"> 0  </p></div><div class="statsContent"><p class="label"> Entreprises engaged trainee</p><p class="data" data-values="40" id="valueEntreprises engaged trainee"> 0  </p></div> </div>
# <footer>
# <a class="button big scrolly" href="#origins">The Origins</a>
# </footer>
# </div>
# <!-- Notre histoire -->
# <div class="wrapper style2">
# <article id="origins">
# <header>
# <h2>Our story</h2>
# <p><a href="https://www.linkedin.com/in/karenboers" rel="noopener" target="_blank">Karen Boers</a>, <a href="https://www.linkedin.com/in/laurent-hublet-70aba710/" target="_blank">Laurent Hublet</a> and <a href="https://www.linkedin.com/in/rodverhaegen" rel="noopener" target="_blank">Rodolphe
# 						Verhaegen</a> have combined their forces around a common goal: to give everyone access to jobs of the future.<br/><br/>
# 					Karen promotes the role of start-ups in the economy.<br/>
# 					Laurent prepares Belgium for the digital opportunity, within the government.<br/>
# 					Rodolphe returns from Silicon Valley.<br/><br/>
# 					All three note the lack of developers, youth unemployment and opportunities in the corporate world.</p>
# <p><br/>In 2016, they sealed a partnership with Simplon, raised funds, brought together an operational and educational team and launched BeCode.</p>
# </header>
# <footer>
# <a class="button big scrolly" href="#who">The Team</a>
# </footer>
# </article>
# </div>
# <!-- Notre équipe -->
# <div class="wrapper style3">
# <article id="who">
# <header>
# <h2>The team</h2>
# <p>Our team brings together managers and educators from a variety of backgrounds.<br/>
# 					What brings us together is the passion for education and the strong desire to give access to a better future thanks to the exciting jobs of the Net.<br/>
# 					Come and meet us in Brussels, Charleroi, Genk, Liège, Antwerp, Ghent and soon in other cities.</p>
# </header>
# <div class="container">
# <!-- Coach Ligne 1  -->
# <div class="row">
# <!-- ...............................Alex................................ -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/pixeline/" rel="noopener" target="_blank"><img alt="Alexandre Plennevaux" src="images/people/alexandre.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/pixeline/" rel="noopener" target="_blank">Alexandre</a></h3>
# <p class="function">Head Coach</p>
# <blockquote class="quote2">Hard work spotlights the character of people: some turn up their sleeves, some turn
# 									up their noses, and some don't turn up at all. <span class="author">– Sam Ewing </span></blockquote>
# <p class="competence2">
# <img alt="PHP" src="./images/php-logo.png" title="PHP"/>
# <img alt="SQL" src="./images/sql.jpg" title="sql"/>
# <img alt="Bash" src="./images/bash.png" title="Bash"/>
# <!--<img src="./images/markdown.png" alt="MarkDown" title="MarkDown">
# 									<img src="./images/HTML_Logo.png" alt="Html" title="html">-->
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Dev Ops" src="./images/devops.jpg" title="devops"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-twitter" href="https://twitter.com/pixeline"></a></li>
# <li><a class="fa fa-github" href="https://github.com/pixeline"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/pixeline/"></a></li>
# <li><a class="fa fa-globe" href="https://pixeline.be"></a></li>
# </ul>
# </article>
# </div>
# <!-- ...................................Emily............................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/emily-m-74989633/" rel="noopener" target="_blank"><img alt="Emily" src="images/people/emily.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/emily-m-74989633/" rel="noopener" target="_blank">Emily</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">People think staying positive is supposed to be easy. In fact, it's some of the
# 									hardest work you'll ever do. But so worth it. <span class="author">– Andrew WK </span></blockquote>
# <p class="competence2">
# <img alt="PHP" src="images/php-logo.png" title="PHP"/>
# <img alt="SQL" src="./images/sql.jpg" title="SQL"/>
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-twitter" href="https://twitter.com/miloon"></a></li>
# <li><a class="fa fa-github" href="https://github.com/webmae"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/emilymrghl/"></a></li>
# <li><a class="fa fa-medium" href="https://medium.com/@webmae"></a></li>
# <!-- <li><a class="fa fa-globe" href="https://dribbble.com/biggles"></a></li> -->
# </ul>
# </article>
# </div>
# <!-- .......................................Bertrand................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/bertrand-marlair-156254150/" rel="noopener" target="_blank"><img alt="Bertrand Marlair" src="images/people/bertrand.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/bertrand-marlair-156254150/" rel="noopener" target="_blank">Bertrand</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">It is by making mistakes that we learn and develop. You have to be bad to become
# 									good. <span class="author">- Anomymous</span></blockquote>
# <p class="competence2">
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# <img alt="React.js" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/bertrandBecode"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/bertrand-marlair/"></a></li>
# <!-- <li><a class="fa fa-globe" href="https://dribbble.com/biggles"></a></li> -->
# </ul>
# </article>
# </div>
# <!-- ....................Ludovic...................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/ludovic-patho-dev/" rel="noopener" target="_blank"><img alt="Ludovic Patho" src="images/people/ludovic.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/ludovic-patho-dev/" rel="noopener" target="_blank">Ludo</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">It is precisely because it is difficult that it is wonderful.<span class="author">–
# 										Tom Hanks </span></blockquote>
# <p class="competence2">
# <img alt="Node.js" src="./images/node-logo.png" title="Node.js"/>
# <img alt="javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="php" src="./images/php-logo.png" title="PHP"/>
# <img alt="Vue.js" src="./images/vue.png" title="Vue.js"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-twitter" href="https://twitter.com/LudovicPatho"></a></li>
# <li><a class="fa fa-github" href="https://github.com/"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/ludovic-patho-dev/"></a></li>
# <li><a class="fa fa-globe" href="http://www.patholudovic.be"></a></li>
# </ul>
# </article>
# </div>
# <!-- ......................................Anthony.................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/anthony-lim%C3%A8re/" rel="noopener" target="_blank"><img alt="Anthony" src="images/people/anthony.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/anthony-lim%C3%A8re/" rel="noopener" target="_blank">Anthony</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote cite="" class="quote2">The more you know, the more you know you don't know. <span class="author">-
# 										Aristotle</span></blockquote>
# <p class="competence2">
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# <img alt="React.js" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="NodeJS" src="./images/node-logo.png" title="Node.js"/>
# <img alt="Ruby On rails" src="./images/rubyonrails.jpg" title="Ruby On Rails"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-twitter" href="https://twitter.com/anthonylimere"></a></li>
# <li><a class="fa fa-github" href="https://github.com/Antholimere"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/anthony-lim%C3%A8re/"></a></li>
# <!-- <li><a class="fa fa-globe" href="https://dribbble.com/biggles"></a></li> -->
# </ul>
# </article>
# </div>
# <!-- ....................Valérian...................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/valerian-thomas/" rel="noopener" target="_blank"><img alt="Valerian Thomas" src="images/people/valerien.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/valerian-thomas/" rel="noopener" target="_blank">Valérian</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">No matter how you feel, get up, show up, boot up, and hit that keyboard hard. But
# 									most importantly : never give up !<span class="author">– Regina Brett </span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="javascript" src="./images/javascript-logo.png" title="javascript"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/valerian-thomas/"></a></li>
# </ul>
# </article>
# </div>
# <!-- ......................Leny.................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/padelnatte" rel="noopener" target="_blank"><img alt="Pierre-Antoine Delnatte" src="images/people/pierreAntoine.png"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/padelnatte" rel="noopener" target="_blank">Leny</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Wisdom comes from experience. Experience is often a result of lack of wisdom.<span class="author">– Terry Pratchett</span></blockquote>
# <p class="competence2">
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="Node.js" src="./images/node-logo.png" title="Node.js"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# <img alt="postgreSQL" src="./images/Postgresql.svg" title="postgreSQL"/>
# <img alt="Docker" src="./images/docker.png" title="Docker"/>
# </p>
# <p class="competence2">
# <img alt="Bash/Shell" src="./images/bash.png" title="Bash/Shell"/>
# <img alt="devops" src="./images/devops.jpg" title="Devops"/>
# <img alt="Python" src="./images/python.png" title="Python"/>
# <img alt="CSS" src="./images/css3.png" title="CSS"/>
# <img alt="MongoDB" src="./images/mongodb.jpg" title="MongoDB"/>
# <img alt="Stylus" src="./images/stylus.png" title="Stylus"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/leny"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/padelnatte"></a></li>
# <li><a class="fa fa-twitter" href="https://twitter.com/leny_be"></a></li>
# <li><a class="fa fa-medium" href="https://medium.com/@leny_be"></a></li>
# <li><a class="fa fa-globe" href="http://www.leny.me"></a></li>
# </ul>
# </article>
# </div>
# <!-- .............................Arnaud.............................. -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/arnaud-duchemin-a28068151/" rel="noopener" target="_blank"><img alt="Arnaud Duchemin" src="images/people/arnaud.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/arnaud-duchemin-a28068151/" rel="noopener" target="_blank">Arnaud</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">It is never too late to be what you might have been.<span class="author">– George
# 										Eliot</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="php" src="./images/php-logo.png" title="PHP"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/Cervant3s"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/arnaud-duchemin-a28068151/"></a></li>
# </ul>
# </article>
# </div>
# <!-- ............................Kevin......................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/kevin-flabat-420a74ba/" rel="noopener" target="_blank"><img alt="Kevin Flabat" id="kevin" src="images/people/kevin.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/kevin-flabat-420a74ba/" rel="noopener" target="_blank">Kevin</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">A journey of a thousand miles begins with a single step.<span class="author">– Lao
# 										Tseu</span></blockquote>
# <p class="competence2">
# <img alt="Node.js" src="./images/node-logo.png" title="Node.js"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# <img alt="Vue.js" src="./images/vue.png"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/keloriane"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/kevin-flabat-420a74ba/"></a></li>
# </ul>
# </article>
# </div>
# <!-- .................................Lesley........................................ -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/lesleyforn" rel="noopener" target="_blank"><img alt="Lesley Forn" src="images/people/leysley.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/lesleyforn" rel="noopener" target="_blank">Lesley</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">You can't cross the sea merely by standing and staring at the water.<span class="author">–
# 										Rabindranath Tagore</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="php" src="./images/php-logo.png" title="PHP"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/ministrare"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/lesleyforn"></a></li>
# </ul>
# </article>
# </div>
# <!-- ......................Marie.................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/marie-thielens/" rel="noopener" target="_blank"><img alt="Marie Thielens" src="images/people/marie.png"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/marie-thielens/" rel="noopener" target="_blank">Marie</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Don't be discouraged, it's often the last key of the keychain that opens the door.<span class="author">– Zig Ziglar</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="Node.js" src="./images/node-logo.png" title="Node.js"/>
# <img alt="WordPress" src="./images/wordpress.png" title="WordPress"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/marieThielens"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/marie-thielens/"></a></li>
# <li><a class="fa fa-globe" href="https://www.thielens-marie.be/"></a></li>
# </ul>
# </article>
# </div>
# <!-- ........................David.................. -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/david-thewissen/" rel="noopener" target="_blank"><img alt="David" src="images/people/david.jpeg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/david-thewissen/" rel="noopener" target="_blank">David</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Experience is simply the name we give our mistakes.<span class="author">– Oscar
# 										Wilde</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/david-thewissen"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/david-thewissen/"></a></li>
# <li><a class="fa fa-twitter" href="https://twitter.com/David_Thewissen"></a></li>
# </ul>
# </article>
# </div>
# <!-- ...................Thijs.............................. -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/thijs-lambert" rel="noopener" target="_blank"><img alt="Thijs Lambert" src="images/people/thijs.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/thijs-lambert" rel="noopener" target="_blank">Thijs</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">A little consideration, a little thought for others, makes all the difference.<span class="author">– Eeyore, Winnie the Pooh</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="Node.js" src="./images/node-logo.png" title="Node.js"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# <img alt="PHP" src="images/php-logo.png" title="PHP"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/Thijs-Lambert"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/thijs-lambert"></a></li>
# </ul>
# </article>
# </div>
# <!-- .............................Nicolas J................................ -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/nicolas-jamar-26123814b/" rel="noopener" target="_blank"><img alt="Nicolas Jamar" src="images/people/nicolasJ.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/nicolas-jamar-26123814b/" rel="noopener" target="_blank">Nicolas</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Never accept defeat, you may be one step away from success.<span class="author">–
# 										Jack E. Addington</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="angular" src="./images/angular.png" title="angular"/>
# <img alt="WordPress" src="./images/wordpress.png" title="WordPress"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/NicolasJamar"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/nicolas-jamar-26123814b/"></a></li>
# </ul>
# </article>
# </div>
# <!-- .............................Nicolas V..................................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/nicolasvanhoren/" rel="noopener" target="_blank"><img alt="Nicolas Vanhoren" src="images/people/vanhoren.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/nicolasvanhoren/" rel="noopener" target="_blank">Nicolas</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Be the change you want to see in the world.<span class="author">– Gandhi</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="Node.js" src="./images/node-logo.png" title="Node.js"/>
# <img alt="PHP" src="images/php-logo.png" title="PHP"/>
# </p>
# <p class="competence2">
# <img alt="SQL" src="./images/sql.jpg" title="SQL"/>
# <img alt="Python" src="./images/python.png" title="Python"/>
# <img alt="C++" src="./images/c++.png" title="C++"/>
# <img alt="Bash/Shell" src="./images/bash.png" title="Bash/Shell"/>
# <img alt="devops" src="./images/devops.jpg" title="Devops"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/nicolas-van"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/nicolasvanhoren/"></a></li>
# <li><a class="fa fa-globe" href="https://nicolas-van.github.io/"></a></li>
# </ul>
# </article>
# </div>
# <!-- .................................Jan....................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/jan-van-den-enden-410b7820/" rel="noopener" target="_blank"><img alt="Jan Van Den Enden" src="images/people/jan.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/jan-van-den-enden-410b7820/" rel="noopener" target="_blank">Jan</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Tell me and I forget. Teach me and I remember. Involve me and I learn.<span class="author">–
# 										Benjamin Franklin</span></blockquote>
# <p class="competence2">
# <img alt="HTML" src="./images/HTML_Logo.png" title="HTML"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/janvandenenden/"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/jan-van-den-enden-410b7820/t"></a></li>
# </ul>
# </article>
# </div>
# <!-- .................................Selene....................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/selene-nijst-112353173/" rel="noopener" target="_blank"><img alt="Selene Nijst" src="images/people/selene.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/selene-nijst-112353173/" rel="noopener" target="_blank">Selene</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">I survived because the fire inside burned brighter than the fire around me.<span class="author"> - Joshua Graham</span></blockquote>
# <p class="competence2">
# <img alt="C#" src="./images/c_sharp.jpg" title="C#"/>
# <img alt="PHP" src="images/php-logo.png" title="PHP"/>
# <img alt="Python" src="./images/python.png" title="Python"/>
# <img alt="React.js" src="./images/javascript-logo.png" title="Javascript"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/SeleneNijst/"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/selene-nijst-112353173/"></a></li>
# </ul>
# </article>
# </div>
# <!-- .................................Rafael....................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/codebull/" rel="noopener" target="_blank"><img alt="Rafael Lambelin" src="images/people/raf.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/codebull/" rel="noopener" target="_blank">Rafael</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">“Always code as if the guy who ends up maintaining your code will be a violent
# 									psychopath who knows where you live.” <span class="author">― John Woods</span></blockquote>
# <p class="competence2">
# <img alt="PHP" src="images/php-logo.png" title="PHP"/>
# <img alt="Laravel" src="./images/laravel.jpg" title="Laravel"/>
# <img alt="C++" src="./images/c++.png" title="C++"/>
# <img alt="C#" src="./images/c_sharp.jpg" title="C#"/>
# <img alt="Arduino" src="./images/arduino.png" title="Arduino"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/rafaello104/"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/codebull/"></a></li>
# </ul>
# </article>
# </div>
# <!-- .................................Filip....................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/filip-smets-870bb994/" rel="noopener" target="_blank"><img alt="Filip Smets" src="images/people/filip.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/filip-smets-870bb994/" rel="noopener" target="_blank">Filip</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">Treat a person as he is, and he will remain as he is. Treat him as he could be, and
# 									he will become what he should be.<span class="author">- Jimmy Johnson</span></blockquote>
# <p class="competence2">
# <img alt="NodeJS" src="./images/node-logo.png" title="Node.js"/>
# <img alt="Unity" src="./images/unity.jpg" title="Unity"/>
# <img alt="Arduino" src="./images/arduino.png" title="Arduino"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/squarific/"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/filip-smets-870bb994/"></a></li>
# <li><a class="fa fa-globe" href="https://www.filipsmets.com"></a></li>
# </ul>
# </article>
# </div>
# <!-- .................................Aravind....................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher animated">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/aravind-chandrashekar-47186316b/" rel="noopener" target="_blank"><img alt="Aravind Chandrashekar" src="images/people/aravind.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/aravind-chandrashekar-47186316b/" rel="noopener" target="_blank">Aravind</a></h3>
# <p class="function">Code Guardian</p>
# <blockquote class="quote2">It does not matter how slowly you go as long as you do not stop. <span class="author">-
# 										Anonymous</span></blockquote>
# <p class="competence2">
# <img alt="Html" src="./images/HTML_Logo.png" title="html"/>
# <img alt="CSS" src="./images/css3.png" title="css"/>
# <img alt="React.js" src="./images/react-logo.png" title="React.js"/>
# <img alt="Javascript" src="./images/javascript-logo.png" title="Javascript"/>
# </p>
# </div>
# <ul class="footer">
# <li><a class="fa fa-github" href="https://github.com/aravindtc/"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/aravind-chandrashekar-47186316b/"></a></li>
# </ul>
# </article>
# </div>
# </div>
# <!-- -->
# <div class="row">
# <!-- .................................Ayaan....................... -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/ayaan-jama-30456b47/" rel="noopener" target="_blank"><img alt="Ayaan Jama" src="images/people/ayaan.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/ayaan-jama-30456b47/" rel="noopener" target="_blank">Ayaan</a></h3>
# <p class="function">Marketing Officer</p>
# <blockquote class="quote2">If you’re always trying to be normal you will never know how amazing you can be.
# 									<span class="author">- Maya Angelou </span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/ayaan-jama/"></a></li>
# <li><a class="fa fa-envelope" href="mailto:ayaan@becode.org  "></a></li>
# </ul>
# </article>
# </div>
# <!-- ...........................Abel.............................. -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/magolu-abel/" rel="noopener" target="_blank"><img alt="Abel Magolu" src="images/people/abel.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/magolu-abel/" rel="noopener" target="_blank">Abel</a></h3>
# <p class="function">Marketing &amp; Community Lead</p>
# <blockquote class="quote2"> I have a dream<span class="author">- Martin Luther King </span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/magolu-abel/"></a></li>
# <li><a class="fa fa-envelope" href="mailto:abel@becode.org "></a></li>
# </ul>
# </article>
# </div>
# <!-- ...........................Tom.............................. -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/tom-crohin-915253138/" rel="noopener" target="_blank"><img alt="Tom Crohin" src="images/people/tom.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/tom-crohin-915253138/" rel="noopener" target="_blank">Tom</a></h3>
# <p class="function">Communication Officer</p>
# <blockquote class="quote2">A lot of people are afraid to say what they want, that's why they don't get what
# 									they want. <span class="author"> - Madonna Ciccone </span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/tomcrohin/"></a></li>
# <li><a class="fa fa-envelope" href="mailto:tom@becode.org "></a></li>
# </ul>
# </article>
# </div>
# <!-- ...........................David.............................. -->
# <div class="3u 4u(tablet) 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/david-c-a95547b8/" rel="noopener" target="_blank"><img alt="David Colantuono" src="images/people/davidcolantuono.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/david-c-a95547b8/" rel="noopener" target="_blank">David</a></h3>
# <p class="function">Marketing &amp; Communication Officer</p>
# <blockquote class="quote2"> He who says he can and he who says he can't are both usually right. <span class="author">-
# 										Confucius </span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/david-c-a95547b8/"></a></li>
# <li><a class="fa fa-envelope" href="mailto:david.colantuono@becode.org "></a></li>
# </ul>
# </article>
# </div>
# </div>
# <!-- -->
# <div class="row">
# <!-- ....................................Eric........................................ -->
# <div class="4u 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/eric-mangitukwa-salla-93364734/" rel="noopener" target="_blank"><img alt="Eric Salla" src="images/people/eric.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/eric-mangitukwa-salla-93364734/" rel="noopener" target="_blank">Eric</a></h3>
# <p class="function">Mediation &amp; Employment Officer</p>
# <blockquote class="quote2">
# 									If I had an hour to solve a problem, I'd spend 55 minutes thinking about the problem and 5 minutes thinking
# 									about solutions.<span class="author">– A Einstein </span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-twitter" href="https://twitter.com/Sallartiste"></a></li>
# <li><a class="fa fa-github" href="https://github.com/sallartiste"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/eric-m-salla/"></a></li>
# <li><a class="fa fa-globe" href="http://www.sallartiste.com"></a></li>
# <li><a class="fa fa-envelope" href="mailto:eric@becode.org  "></a></li>
# </ul>
# </article>
# </div>
# <!-- ..........................Ayoub................................................... -->
# <div class="4u 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/ayoub-mohyi/" rel="noopener" target="_blank"><img alt="Ayoub Mohyi" src="images/people/ayoub.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/ayoub-mohyi/" rel="noopener" target="_blank">Ayoub</a></h3>
# <p class="function">Mediation &amp; Employment Officer</p>
# <blockquote class="quote2">ERROR: Quotation not found<span class="author">- Author request not found</span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/ayoub-mohyi/"></a></li>
# <li><a class="fa fa-envelope" href="mailto:ayoub@becode.org"></a></li>
# </ul>
# </article>
# </div>
# </div>
# <div class="row">
# <div class="4u 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/karenboers" rel="noopener" target="_blank"><img alt="Karen Boers" src="images/people/karen.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/karenboers" rel="noopener" target="_blank">Karen</a></h3>
# <p class="function">CEO</p>
# <blockquote class="quote2"> If you never failed, then probably you did not try hard enough.<span class="author">-
# 										Neelie Kroes </span></blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-twitter" href="https://twitter.com/karenboers"></a></li>
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/karenboers"></a></li>
# <!-- <li><a class="fa fa-globe" href="https://dribbble.com/biggles"></a></li> -->
# </ul>
# </article>
# </div>
# <div class="4u 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/sarah-unger-6a33583/" rel="noopener" target="_blank"><img alt="Sarah Unger" src="images/people/sarah.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/sarah-unger-6a33583/" rel="noopener" target="_blank">Sarah</a></h3>
# <p class="function">CFO</p>
# <blockquote class="quote2">
# 									The only limit to the height of your achievements is the reach of your dreams and your willingness to work
# 									hard for them <span class="author">- Michelle Obama</span>
# </blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/sarah-unger-6a33583/"></a></li>
# </ul>
# </article>
# </div>
# <div class="4u 12u(mobile)">
# <article class="box style2 teacher noAnim">
# <figure>
# <a class="image featured" href="https://www.linkedin.com/in/miriam-azzouz/" rel="noopener" target="_blank"><img alt="Miriam Azzouz" src="images/people/miriam.jpg"/></a>
# </figure>
# <div class="content_card">
# <h3><a href="https://www.linkedin.com/in/miriam-azzouz/" rel="noopener" target="_blank">Miriam</a></h3>
# <p class="function">Office Angel</p>
# <blockquote class="quote2">
# 									Dans la vie, rien n'est à craindre tout est à comprendre" <span class="author">- Marie Curie</span>
# </blockquote>
# </div>
# <ul class="footer">
# <li><a class="fa fa-linkedin" href="https://www.linkedin.com/in/miriam-azzouz/"></a></li>
# </ul>
# </article>
# </div>
# </div>
# </div>
# <footer>
# <!--<p>BeCode is a not-for-profit association, created by <a target="_blank" href="https://www.linkedin.com/in/rodverhaegen">Rodolphe Verhaegen</a>, <a target="_blank" href="https://www.linkedin.com/in/laurent-hublet-70aba710">Laurent Hublet</a>, <a target="_blank" href="https://www.linkedin.com/in/karenboers">Karen Boers</a>, <a target="_blank" href="https://www.linkedin.com/in/sarah-unger-6a33583">Sarah Unger</a> and <a target="_blank" href="https://www.linkedin.com/in/dirkpeusens">Dirk Peusens</a>.
# 				</p>
# 				<p>Karen is leading the management team with <a target="_blank" href="https://be.linkedin.com/in/cyance">Cedric Swaelens</a> (head of faculty / BeCode Brussels).</p>
# 				<p>BeCode can count on the support of these fantastic partners:</p>-->
# <a class="button big scrolly" href="#partners">Our partners</a>
# </footer>
# </article>
# </div>
# <!--...................... Section : Partners  .......................... -->
# <div class="wrapper style1">
# <article id="partners">
# <header>
# <h2>Our partners</h2>
# </header>
# <div class="container">
# <div class="row">
# <div class="3u 4u(medium) 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.telenet.be" rel="noopener" target="_blank"><img alt="Telenet logo" src="../img/partners/telenet.png"/></a>
# <h3><a href="http://www.telenet.be" rel="noopener" target="_blank">Telenet</a></h3>
# <p>Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.orange.be" rel="noopener" target="_blank"><img alt="Orange logo" src="../img/partners/orange.png"/></a>
# <h3><a href="http://www.orange.be" rel="noopener" target="_blank">Orange</a></h3>
# <p>Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.4wings.org/" rel="noopener" target="_blank"><img alt="4Wings" src="../img/partners/4wings.png"/></a>
# <h3><a href="https://www.4wings.org/" rel="noopener" target="_blank">4Wings</a></h3>
# <p>Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.degroofpetercam.be" rel="noopener" target="_blank"><img alt="Degroof Petercam logo" src="../img/partners/degroof.jpg"/></a>
# <h3><a href="http://www.degroofpetercam.be" rel="noopener" target="_blank">Degroof Petercam</a></h3>
# <p>Donor</p>
# </article>
# </div>
# </div> <!-- Fin row -->
# <div class="row">
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.jpmorgan.com/country/BE/en/technology-at-our-firm" rel="noopener" target="_blank"><img alt="J.P.Morgan" src="../img/partners/JpMorgan.png" style="padding: 48px 30px 64px;"/></a>
# <h3><a href="https://www.jpmorgan.com/country/BE/en/technology-at-our-firm" rel="noopener" target="_blank">J.P.Morgan</a></h3>
# <p>Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://fondation-engie.com/en/the-engie-foundation/" rel="noopener" target="_blank"><img alt="Engie Foundation" src="../img/partners/engieFondation.jpg" style="padding-bottom:19px;"/></a>
# <h3><a href="https://fondation-engie.com/en/the-engie-foundation/" rel="noopener" target="_blank">Engie Foundation</a></h3>
# <p>Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://digitalbelgium.be" rel="noopener" target="_blank"><img alt="Digital Belgium" src="../img/partners/dbsf.png"/></a>
# <h3><a href="http://digitalbelgium.be" rel="noopener" target="_blank">Digital Belgium</a></h3>
# <p>Public Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.spfb.brussels/" rel="noopener" target="_blank"><img alt="COCOF logo" src="../img/partners/cocof.png"/></a>
# <h3><a href="http://www.spfb.brussels/" rel="noopener" target="_blank">COCOF</a></h3>
# <p>Public Donor</p>
# </article>
# </div>
# </div> <!-- Fin row -->
# <div class="row">
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.digitalwallonia.be/fr" rel="noopener" target="_blank"><img alt="Digital Wallonia logo" src="../img/partners/wallonia.jpg" style="width : 190px; margin : 0 auto; padding-top : 27px"/></a>
# <h3><a href="https://www.digitalwallonia.be/fr" rel="noopener" target="_blank">Digital Wallonia</a></h3>
# <p>Public Donor</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://close-the-gap.org" rel="noopener" target="_blank"><img alt="Close the Gap logo" src="../img/partners/closethegap.png"/></a>
# <h3><a href="http://close-the-gap.org" rel="noopener" target="_blank">Close The Gap</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.vow.be/" rel="noopener" target="_blank"><img alt="Van Olmen-Wynant logo" src="../img/partners/vowlogo.jpg"/></a>
# <h3><a href="http://www.vow.be/" rel="noopener" target="_blank">Van Olmen - Wynant</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.bruxellesformation.be/" rel="noopener" target="_blank"><img alt="Bruxelles Formation logo" src="../img/partners/bxlformation.png"/></a>
# <h3><a href="http://www.bruxellesformation.be/" rel="noopener" target="_blank">Bxl Formation</a></h3>
# <p>Partner</p>
# </article>
# </div>
# </div> <!-- Fin row -->
# <div class="row">
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.vdab.be/" rel="noopener" target="_blank"><img alt="VDAB logo" src="../img/partners/vdab.jpg" style="width:180px; margin :auto;"/></a>
# <h3><a href="http://www.vdab.be/" rel="noopener" target="_blank">VDAB</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.leforem.be/" rel="noopener" target="_blank"><img alt="FOREM logo" src="../img/partners/forem.jpg"/></a>
# <h3><a href="http://www.leforem.be/" rel="noopener" target="_blank">Le Forem</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://www.cevora.be/" rel="noopener" target="_blank"><img alt="CEVORA logo" src="../img/partners/cevora.png" style="padding-top :45px; padding-bottom: 11px; margin-top : 0;"/></a>
# <h3><a href="http://www.cevora.be/" rel="noopener" target="_blank">Cevora</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="http://simplon.co" rel="noopener" target="_blank"><img alt="Simplon logo" src="../img/partners/simplon.png"/></a>
# <h3><a href="http://simplon.co" rel="noopener" target="_blank">Simplon.co</a></h3>
# <p>Partner</p>
# </article>
# </div>
# </div> <!-- Fin row -->
# <div class="row" style="justify-content:center !important;">
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://learndigital.withgoogle.com/digitaalatelier" rel="noopener" target="_blank"><img alt="Google Digital Atelier" src="../img/partners/googleAtelierDigital.png" style="padding: 43px 30px 41px;"/></a>
# <h3><a href="https://learndigital.withgoogle.com/digitaalatelier" rel="noopener" target="_blank">Google Digital Atelier</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.ibm.com/be-en/" rel="noopener" target="_blank"><img alt="ibm logo" src="../img/partners/ibm.png" style="padding: 43px 30px 36px;"/></a>
# <h3><a href="https://www.ibm.com/be-en/" rel="noopener" target="_blank">IBM</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.microsoft.com/" rel="noopener" target="_blank"><img alt="microsoft logo" src="../img/partners/microsoft_black.png" style="padding: 55px 30px 30px;"/></a>
# <h3><a href="https://www.microsoft.com/" rel="noopener" target="_blank">Microsoft</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.datacamp.com/" rel="noopener" target="_blank"><img alt="datacamp logo" src="../img/partners/datacamp.png" style="padding: 58px 30px 57px;"/></a>
# <h3><a href="https://www.datacamp.com/" rel="noopener" target="_blank">Datacamp</a></h3>
# <p>Partner</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.bcg.com/" rel="noopener" target="_blank"><img alt="bcg logo" src="../img/partners/bcg-logo.jpg" style="padding: 60px 30px 60px;"/></a>
# <h3><a href="https://www.bcg.com/" rel="noopener" target="_blank">BCG</a></h3>
# <p>Partner</p>
# </article>
# </div>
# </div>
# </div> <!-- Fin container -->
# <!-- 		</div>  Fin class="wrapper style1" -->
# <footer>
# <a class="button big scrolly" href="#theboard">The Board</a>
# </footer>
# </article> <!-- id="partners"-->
# </div> <!--  Fin class="wrapper style1" -->
# <!-- administration -->
# <div class="wrapper style2">
# <article id="theboard">
# <header>
# <h2>Board of directors</h2>
# </header>
# <div class="container">
# <div class="row">
# <div class="4u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/karenboers/" rel="noopener" target="_blank"><img alt="Karen Boers" src="images/people/karen2.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/karenboers/" rel="noopener" target="_blank">Karen</a></h3>
# <p>Co-founder, CEO</p>
# </article>
# </div>
# <div class="4u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/laurent-hublet-70aba710/" rel="noopener" target="_blank"><img alt="Laurent Hublet" src="images/people/laurent.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/laurent-hublet-70aba710/" rel="noopener" target="_blank">Laurent</a></h3>
# <p>Co-founder, board observer</p>
# </article>
# </div>
# <div class="4u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/rodverhaegen/" rel="noopener" target="_blank"><img alt="Rodolphe Verhaegen" src="images/people/rodolphe.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/rodverhaegen/" rel="noopener" target="_blank">Rodolphe</a></h3>
# <p>Co-founder, chairman</p>
# </article>
# </div>
# </div>
# <div class="row">
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/ineke-rampart-824a521/" rel="noopener" target="_blank"><img alt="Ineke Rampart" src="images/people/ineke.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/ineke-rampart-824a521/" rel="noopener" target="_blank">Ineke</a></h3>
# <p>Telenet</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/paul-marie-dessart-7513a824/" rel="noopener" target="_blank"><img alt="Paul Marie Dessart" src="images/people/paulmarie.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/paul-marie-dessart-7513a824/" rel="noopener" target="_blank">Paul-Marie</a></h3>
# <p>Orange</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/matthieuspeeckaert/" rel="noopener" target="_blank"><img alt="Matthieu Speeckaert" src="images/people/matthieu.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/matthieuspeeckaert/" rel="noopener" target="_blank">Matthieu</a></h3>
# <p>4Wings Foundation</p>
# </article>
# </div>
# <div class="3u 12u(mobile)">
# <article class="box style2">
# <a class="image featured" href="https://www.linkedin.com/in/fredericbardeau/" rel="noopener" target="_blank"><img alt="Frédéric Bardeau" src="images/people/fred.jpg"/></a>
# <h3><a href="https://www.linkedin.com/in/fredericbardeau/" rel="noopener" target="_blank">Frédéric</a></h3>
# <p>Simplon</p>
# </article>
# </div>
# </div>
# </div>
# <footer>
# <a class="button big scrolly" href="#work">Help us!</a>
# </footer>
# </article>
# </div>
# <!-- Work -->
# <div class="wrapper style3">
# <article id="work">
# <header>
# <h2>Here's how you can make a difference.</h2>
# </header>
# <div class="container">
# <div class="row">
# <div class="3u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-child"></span>
# <h3>BeComing a Student</h3>
# <p>You look for an alternative and efficient way of learning code.</p>
# <p>Register for the free training.</p>
# <a class="button" href="http://register.becode.org" target="_blank">Let's Go !</a>
# </section>
# </div>
# <div class="3u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-comments-o"></span>
# <h3>BeComing a Speaker</h3>
# <p>Our students need to be in touch with inspirational speakers from corporate and associative worlds.</p>
# <p>Join us for a few hours.</p>
# <a class="button" href="https://docs.google.com/forms/d/1OqhjehbYvBhCRjE75GKKZx60Lk-6vhKD6n4l2s4g4RU/edit" target="_blank">Let's Go !</a>
# </section>
# </div>
# <div class="3u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-magic"></span>
# <h3>BeComing a Teacher</h3>
# <p>That's where the magic happens. You can bring 24 students to an active professional life.</p>
# <p>Join us for a position.</p>
# <a class="button" href="https://docs.google.com/forms/d/1OqhjehbYvBhCRjE75GKKZx60Lk-6vhKD6n4l2s4g4RU/edit" target="_blank">Let's Go !</a>
# </section>
# </div>
# <div class="3u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-thumbs-o-up"></span>
# <h3>BeComing a Friend</h3>
# <p>Join the partners program and help us to bridge the gap between workforce and jobs.</p>
# <p>Be part of it!</p>
# <a class="button" href="https://docs.google.com/forms/d/e/1FAIpQLSei592hU4K0QDZUdAal5-8jhn4yro_9qGG3rHjZWssC1PAg8w/viewform" target="_blank">Let's Go !</a>
# </section>
# </div>
# </div>
# </div>
# <footer>
# <a class="button big scrolly" href="#portfolio">Spread the word!</a>
# </footer>
# </article>
# </div>
# <!-- Portfolio -->
# <div class="wrapper style1">
# <article id="portfolio">
# <header>
# <h2>Goodies and Ready-To-Share Content</h2>
# </header>
# <div class="container">
# <div class="row">
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-facebook-official"></span>
# <h3><a href="downloads/BeCode_Social.zip">Facebook &amp; LinkedIn</a></h3>
# <p>Share your support!</p>
# </section>
# </div>
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-code"></span>
# <h3><a href="downloads/BeCode_Logos.zip">Logo Kit</a></h3>
# <p>Corporate Identity</p>
# </section>
# </div>
# <div class="4u 12u(mobile)">
# <section class="box style1">
# <span class="icon featured fa-desktop"></span>
# <h3><a href="downloads/BeCode_Wallpapers.zip">Wallpapers</a></h3>
# <p>Because your laptop deserves it ;-)</p>
# </section>
# </div>
# </div>
# </div>
# <footer>
# <a class="button big scrolly" href="#contact">Get in touch with us</a>
# </footer>
# </article>
# </div>
# <!-- Contact -->
# <div class="wrapper style4">
# <article class="container 75%" id="contact">
# <div>
# <div class="row">
# <div class="12u">
# <hr/>
# <h3>Contact us through ...</h3>
# <ul class="social">
# <li><a class="icon alt fa-envelope" href="https://mailhide.io/e/rQdpc"><span class="label">Email</span></a></li>
# <li><a class="icon alt fa-facebook" href="https://www.facebook.com/becode.org" rel="noopener" target="_blank"><span class="label">Facebook</span></a></li>
# <li><a class="icon alt fa-youtube-play" href="https://www.youtube.com/channel/UCgE_Zvt-uWmsc0x6r82VAFQ" rel="noopener" target="_blank"><span class="label">YouTube</span></a></li>
# <li><a class="icon alt fa-linkedin" href="https://www.linkedin.com/company/becode.org" rel="noopener" target="_blank"><span class="label">LinkedIn</span></a></li>
# <li><a class="icon alt fa-twitter" href="https://twitter.com/becodeorg" rel="noopener" target="_blank"><span class="label">Twitter</span></a></li>
# <li><a class="icon alt fa-medium" href="http://blog.becode.org" rel="noopener" target="_blank"><span class="label">Blog</span></a></li>
# </ul>
# <hr/>
# </div>
# </div>
# </div>
# </article>
# <!-- footer -->
# <footer>
# <ul id="copyright">
# <li>© BeCode.org © All rights reserved.</li>
# <li>VAT: BE0664.802.168</li>
# </ul>
# </footer>
# </div>
# <!-- Scripts -->
# <script src="assets/js/jquery.min.js"></script>
# <script src="assets/js/jquery.scrolly.min.js"></script>
# <script src="assets/js/skel.min.js"></script>
# <script src="assets/js/skel-viewport.min.js"></script>
# <script src="assets/js/util.js"></script>
# <!--[if lte IE 8]><script src="assets/js/ie/respond.min.js"></script><![endif]-->
# <script src="assets/js/main.js"></script>
# <script>
# 		(function (i, s, o, g, r, a, m) {
# 			i['GoogleAnalyticsObject'] = r;
# 			i[r] = i[r] || function () {
# 				(i[r].q = i[r].q || []).push(arguments)
# 			}, i[r].l = 1 * new Date();
# 			a = s.createElement(o),
# 				m = s.getElementsByTagName(o)[0];
# 			a.async = 1;
# 			a.src = g;
# 			m.parentNode.insertBefore(a, m)
# 		})(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
# 		ga('create', 'UA-89554561-1', 'auto');
# 		ga('send', 'pageview');
# 	</script>
# </body>
# </html>

# %% [markdown]
# We have thus retrieved the information from the site without physically saving it in a file, only in a variable!
#
# Display the main title, the subtitles of and the paragraphs and their descriptions again to convince you
